# %%
import pandas as pd

# %%
# Reading the CSV file
data = pd.read_csv("./Sleep_health_and_lifestyle_dataset.csv")
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
data.head(6)
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
# 5                 4                       30             8        Obese
#
# ...

# %%
data.tail(6)
# Out:
#      Person ID  Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 368        369  Female   59      Nurse             8.1                 9
# 369        370  Female   59      Nurse             8.1                 9
# 370        371  Female   59      Nurse             8.0                 9
# 371        372  Female   59      Nurse             8.1                 9
# 372        373  Female   59      Nurse             8.1                 9
# 373        374  Female   59      Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 368                       75             3   Overweight         140/95
# 369                       75             3   Overweight         140/95
# 370                       75             3   Overweight         140/95
# 371                       75             3   Overweight         140/95
# 372                       75             3   Overweight         140/95
# ...

# %%
data.shape
# Out:
# (374, 13)

# %%
#iloc - for rown indexing
#loc - column indexing

data.iloc[5]
# Out:
# Person ID                                  6
# Gender                                  Male
# Age                                       28
# Occupation                 Software Engineer
# Sleep Duration                           5.9
# Quality of Sleep                           4
# Physical Activity Level                   30
# Stress Level                               8
# BMI Category                           Obese
# Blood Pressure                        140/90
# Heart Rate                                85
# Daily Steps                             3000
# Sleep Disorder                      Insomnia
# Name: 5, dtype: object

# %%
data.iloc[3:7]
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
# 5          6   Male   28     Software Engineer             5.9
# 6          7   Male   29               Teacher             6.3
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
# 5                 4                       30             8        Obese
# 6                 6                       40             7        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea
# 5         140/90          85         3000       Insomnia
# 6         140/90          82         3500       Insomnia

# %%
data
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
data.iloc[1:4,5:7]
# Out:
#    Quality of Sleep  Physical Activity Level
# 1                 6                       60
# 2                 6                       60
# 3                 4                       30

# %%
data.loc[: ,'Occupation']
# Out:
# 0         Software Engineer
# 1                    Doctor
# 2                    Doctor
# 3      Sales Representative
# 4      Sales Representative
#                ...
# 369                   Nurse
# 370                   Nurse
# 371                   Nurse
# 372                   Nurse
# 373                   Nurse
# Name: Occupation, Length: 374, dtype: object

# %%
#renaming the columns
data = data.rename(columns={'Occupation':'Job'})
data
# Out:
#      Person ID  Gender  Age                   Job  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
#add new columns 
data.loc[data['Sleep Duration']<=8,'Classification']='Normal'
data.loc[data['Sleep Duration']>8,'Classification']='Adequate'
data
# Out:
#      Person ID  Gender  Age                   Job  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Job                      374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
#  13  Classification           374 non-null    object
# ...

# %%
#stripping whitespaces
data.columns = data.columns.str.strip()
data.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Job', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder', 'Classification'],
#       dtype='object')

# %%
#Visualization 
#Quality of sleep and sleep duration 
#sleep duration and age 
#box plots

# %%
#graphical rep
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
x = data['Physical Activity Level']
y = data['Quality of Sleep']

# %%
plt.scatter(x,y)
plt.title('Quality of sleep vs Physical activity level')
plt.legend
plt.xlabel('Physical activity level')
plt.ylabel('Quality of sleep')
plt.show()

# %%
#there is a no correlation between quality of sleep and physical activity

# %%
x1 = data['Sleep Duration']
y1 = data['Age']

# %%
plt.bar(x1,y1, edgecolor = 'black', label='age')
plt.title('Age vs Sleep duration')
plt.xlabel('Sleep duration')
plt.ylabel('Age')
plt.legend()
plt.show()

# %%
x2 = data['Quality of Sleep']

# %%
plt.hist(x2,bins=5, edgecolor = 'red', label='Sleep duration')
plt.title('Quality of sleep')
plt.xlabel('number of hours')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
sns.lineplot(data= data, y='Quality of Sleep' , x= 'Physical Activity Level')
plt.title('Physical Activity Level vs Quality of Sleep')
plt.xlabel('Physical Activity Level')
plt.ylabel('Quality of Sleep')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
